# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats

# %%
my = 0 # gjennomsnitt
sigma = 0.5 # standardavvik

norm_dist = np.random.normal(my, sigma, 100000)
sns.histplot(data=norm_dist, bins=20)
plt.show()

# %%
pop_mean = norm_dist.mean()

# %%
pop_std = norm_dist.std()

# %%
delta_mean = []
delta_std = []

for n in np.linspace(10,5000,50):
    samples = np.random.choice(norm_dist, int(n))
    print("Antall samples: ", int(n))
    print("Gjennomsnitt: ", samples.mean())
    print("Standardavvik:", samples.std())
    print("Er normalfordelt: ", stats.normaltest(samples))
    delta_mean.append(samples.mean()- pop_mean)
    delta_std.append(samples.std() - pop_std)

    sns.histplot(data=samples, kde=True, bins=20)

    plt.show()
# Out:
# Antall samples:  10
# Gjennomsnitt:  0.07519804181266673
# Standardavvik: 0.4572076205719172
# Er normalfordelt:  NormaltestResult(statistic=1.1297003767745741, pvalue=0.5684453000860474)
# C:\Users\Bjorn\anaconda3\envs\new_tf\lib\site-packages\scipy\stats\_axis_nan_policy.py:531: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=10
#   res = hypotest_fun_out(*samples, **kwds)
# Antall samples:  111
# Gjennomsnitt:  -0.08099499358650245
# Standardavvik: 0.5055265732449137
# Er normalfordelt:  NormaltestResult(statistic=4.704261936087046, pvalue=0.09516614996166708)
# Antall samples:  213
# Gjennomsnitt:  0.04631856720645661
# Standardavvik: 0.5068074853691638
# Er normalfordelt:  NormaltestResult(statistic=0.6805851600004683, pvalue=0.7115621034632957)
# Antall samples:  315
# Gjennomsnitt:  0.022933685987548524
# Standardavvik: 0.5193757096517255
# Er normalfordelt:  NormaltestResult(statistic=1.4331944631880715, pvalue=0.48841138236865145)
# Antall samples:  417
# Gjennomsnitt:  0.02420666133639798
# Standardavvik: 0.4916498787457829
# Er normalfordelt:  NormaltestResult(statistic=0.35986725478645065, pvalue=0.8353256523124228)
# Antall samples:  519
# Gjennomsnitt:  0.02568141367195852
# Standardavvik: 0.4937706626570776
# Er normalfordelt:  NormaltestResult(statistic=3.7070242240902957, pvalue=0.15668590038837277)
# Antall samples:  621
# Gjennomsnitt:  0.012673707051917206
# Standardavvik: 0.49240535785935824
# Er normalfordelt:  NormaltestResult(statistic=0.3908145159826005, pvalue=0.82249962029404)
# Antall samples:  722
# Gjennomsnitt:  -0.00455268929208661
# Standardavvik: 0.4894243778304315
# Er normalfordelt:  NormaltestResult(statistic=0.5569092158140667, pvalue=0.7569526266340888)
# Antall samples:  824
# Gjennomsnitt:  0.010451320595769876
# Standardavvik: 0.4961795201257311
# Er normalfordelt:  NormaltestResult(statistic=9.389167523183072, pvalue=0.009144672939932971)
# Antall samples:  926
# Gjennomsnitt:  0.02131697745863657
# Standardavvik: 0.5002151053436484
# Er normalfordelt:  NormaltestResult(statistic=0.11799144916175391, pvalue=0.942710799632264)
# Antall samples:  1028
# Gjennomsnitt:  0.01558710019187258
# Standardavvik: 0.4944482793660068
# Er normalfordelt:  NormaltestResult(statistic=0.5133750809411419, pvalue=0.7736098977898695)
# Antall samples:  1130
# Gjennomsnitt:  0.004423275144363496
# Standardavvik: 0.4895924538039357
# Er normalfordelt:  NormaltestResult(statistic=0.8823074112533053, pvalue=0.6432938210936306)
# Antall samples:  1232
# Gjennomsnitt:  0.011604472188343144
# Standardavvik: 0.503451522467223
# Er normalfordelt:  NormaltestResult(statistic=4.293697629252946, pvalue=0.11685179989773989)
# Antall samples:  1333
# Gjennomsnitt:  0.005957517519483697
# Standardavvik: 0.5150643665498319
# Er normalfordelt:  NormaltestResult(statistic=0.23652968070147773, pvalue=0.8884607212043448)
# Antall samples:  1435
# Gjennomsnitt:  0.010955780870176903
# Standardavvik: 0.5065520056169699
# Er normalfordelt:  NormaltestResult(statistic=0.19659151613727108, pvalue=0.9063807946748822)
# Antall samples:  1537
# Gjennomsnitt:  0.012900095342392177
# Standardavvik: 0.4884767749555409
# Er normalfordelt:  NormaltestResult(statistic=0.9251967764539388, pvalue=0.6296454547640358)
# Antall samples:  1639
# Gjennomsnitt:  -0.0002566651731129493
# Standardavvik: 0.5025953996932895
# Er normalfordelt:  NormaltestResult(statistic=1.5591097778243772, pvalue=0.4586100983209024)
# Antall samples:  1741
# Gjennomsnitt:  -0.018475202503455617
# Standardavvik: 0.5043182287084351
# Er normalfordelt:  NormaltestResult(statistic=10.226221436156433, pvalue=0.006017335545349253)
# Antall samples:  1843
# Gjennomsnitt:  -0.018871449522338577
# Standardavvik: 0.5006424571358792
# Er normalfordelt:  NormaltestResult(statistic=2.383803331215393, pvalue=0.30364328668573204)
# Antall samples:  1944
# Gjennomsnitt:  -0.0028797355157756128
# Standardavvik: 0.4985971464468943
# Er normalfordelt:  NormaltestResult(statistic=1.1684601569778343, pvalue=0.557534954761883)
# Antall samples:  2046
# Gjennomsnitt:  0.027162604975950286
# Standardavvik: 0.5010418015606628
# Er normalfordelt:  NormaltestResult(statistic=1.0993217021138089, pvalue=0.5771455154836098)
# Antall samples:  2148
# Gjennomsnitt:  -0.0012626144783694218
# Standardavvik: 0.5104857267872096
# Er normalfordelt:  NormaltestResult(statistic=1.1740117510792087, pvalue=0.5559894968099315)
# Antall samples:  2250
# Gjennomsnitt:  0.0048289943158313885
# Standardavvik: 0.5091089289611489
# Er normalfordelt:  NormaltestResult(statistic=0.6469345114319203, pvalue=0.7236356524657953)
# Antall samples:  2352
# Gjennomsnitt:  -0.014854197396382883
# Standardavvik: 0.49318173129614196
# Er normalfordelt:  NormaltestResult(statistic=2.3597583219265035, pvalue=0.30731587211146066)
# Antall samples:  2454
# Gjennomsnitt:  0.030672501370010298
# Standardavvik: 0.5147329491844965
# Er normalfordelt:  NormaltestResult(statistic=0.3844267029300273, pvalue=0.8251308068443769)
# Antall samples:  2555
# Gjennomsnitt:  0.0030630661712437992
# Standardavvik: 0.4936270556314722
# Er normalfordelt:  NormaltestResult(statistic=0.7227206294549121, pvalue=0.6967279119068068)
# Antall samples:  2657
# Gjennomsnitt:  0.0014633617394617029
# Standardavvik: 0.4996393807518805
# Er normalfordelt:  NormaltestResult(statistic=4.340909207044765, pvalue=0.11412572316044614)
# Antall samples:  2759
# Gjennomsnitt:  -0.008757700097658912
# Standardavvik: 0.5001149446283503
# Er normalfordelt:  NormaltestResult(statistic=8.754569975498278, pvalue=0.01255941132901895)
# Antall samples:  2861
# Gjennomsnitt:  -0.0018924472452800112
# Standardavvik: 0.4965975497803843
# Er normalfordelt:  NormaltestResult(statistic=2.9306879001851898, pvalue=0.23099852584765368)
# Antall samples:  2963
# Gjennomsnitt:  -0.01377426190170658
# Standardavvik: 0.4986422245057885
# Er normalfordelt:  NormaltestResult(statistic=2.065923220323366, pvalue=0.3559512092605141)
# Antall samples:  3065
# Gjennomsnitt:  0.013635992645764343
# Standardavvik: 0.4982082016484164
# Er normalfordelt:  NormaltestResult(statistic=5.85658976502299, pvalue=0.05348816403687013)
# Antall samples:  3166
# Gjennomsnitt:  0.0028848763978802042
# Standardavvik: 0.5001016090614692
# Er normalfordelt:  NormaltestResult(statistic=2.014665454627794, pvalue=0.36519174764963996)
# Antall samples:  3268
# Gjennomsnitt:  -0.0017401017506504426
# Standardavvik: 0.5060149657709194
# Er normalfordelt:  NormaltestResult(statistic=2.316573577344011, pvalue=0.31402370927725615)
# Antall samples:  3370
# Gjennomsnitt:  0.003290039618395965
# Standardavvik: 0.49234318802357024
# Er normalfordelt:  NormaltestResult(statistic=0.12888407208980743, pvalue=0.9375904591382848)
# Antall samples:  3472
# Gjennomsnitt:  -0.007144334532346578
# Standardavvik: 0.5027480982908137
# Er normalfordelt:  NormaltestResult(statistic=0.3783752426351653, pvalue=0.8276312108685298)
# Antall samples:  3574
# Gjennomsnitt:  -0.007634216635274035
# Standardavvik: 0.5072912915797975
# Er normalfordelt:  NormaltestResult(statistic=3.0032082900875903, pvalue=0.22277251394279435)
# Antall samples:  3676
# Gjennomsnitt:  0.00308084053133257
# Standardavvik: 0.49814959397654723
# Er normalfordelt:  NormaltestResult(statistic=6.088137984884061, pvalue=0.047640645147773567)
# Antall samples:  3777
# Gjennomsnitt:  0.003079401998408684
# Standardavvik: 0.49905362777649254
# Er normalfordelt:  NormaltestResult(statistic=2.110544599252316, pvalue=0.34809762754596646)
# Antall samples:  3879
# Gjennomsnitt:  0.0035535740745629273
# Standardavvik: 0.5060384234855548
# Er normalfordelt:  NormaltestResult(statistic=1.4208772861109664, pvalue=0.4914285884391373)
# Antall samples:  3981
# Gjennomsnitt:  0.0034206980078681734
# Standardavvik: 0.5056116274085598
# Er normalfordelt:  NormaltestResult(statistic=1.8977989643453983, pvalue=0.3871668731299609)
# Antall samples:  4083
# Gjennomsnitt:  -0.012429869086070957
# Standardavvik: 0.5001279051199586
# Er normalfordelt:  NormaltestResult(statistic=2.2198658865734413, pvalue=0.3295810609569148)
# Antall samples:  4185
# Gjennomsnitt:  -0.0013328625569865484
# Standardavvik: 0.4981824894391696
# Er normalfordelt:  NormaltestResult(statistic=0.3681531882832937, pvalue=0.8318720848581534)
# Antall samples:  4287
# Gjennomsnitt:  0.010336720260591466
# Standardavvik: 0.4991959830206757
# Er normalfordelt:  NormaltestResult(statistic=0.2963013762558114, pvalue=0.8623011666029691)
# Antall samples:  4388
# Gjennomsnitt:  0.0037823715081097254
# Standardavvik: 0.4917022522957725
# Er normalfordelt:  NormaltestResult(statistic=0.4963215495700735, pvalue=0.7802344911609412)
# Antall samples:  4490
# Gjennomsnitt:  -0.0002253469572293534
# Standardavvik: 0.5029345751430934
# Er normalfordelt:  NormaltestResult(statistic=3.500814002347114, pvalue=0.17370323164239768)
# Antall samples:  4592
# Gjennomsnitt:  0.015937523261608147
# Standardavvik: 0.508017344252935
# Er normalfordelt:  NormaltestResult(statistic=1.2576163937510487, pvalue=0.5332269239749992)
# Antall samples:  4694
# Gjennomsnitt:  0.0076300947465317535
# Standardavvik: 0.4991421013242205
# Er normalfordelt:  NormaltestResult(statistic=2.0254830656780545, pvalue=0.36322182876382225)
# Antall samples:  4796
# Gjennomsnitt:  0.00972280628858878
# Standardavvik: 0.504906438682426
# Er normalfordelt:  NormaltestResult(statistic=1.6548982418169844, pvalue=0.43716301521884093)
# Antall samples:  4898
# Gjennomsnitt:  -0.0025068342694344243
# Standardavvik: 0.4988488104357683
# Er normalfordelt:  NormaltestResult(statistic=1.1900237529801658, pvalue=0.5515560152793851)
# Antall samples:  5000
# Gjennomsnitt:  -0.002466510222264314
# Standardavvik: 0.5052873209584472
# Er normalfordelt:  NormaltestResult(statistic=1.1935328075077951, pvalue=0.5505891436623949)

# %%
plt.plot(delta_std, label="forskjell i standardavvik")
plt.plot(delta_mean, label="forskjell i gjennomsnitt")
plt.hlines(xmin=0,xmax=50, y=0, linestyle='--', colors="k")
plt.legend()
plt.show()
