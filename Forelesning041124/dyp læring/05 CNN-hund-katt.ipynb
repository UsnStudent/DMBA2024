# %%
import tensorflow as tf
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from sklearn.model_selection import  train_test_split 
import math
from tensorflow.keras.utils import to_categorical
import os
import cv2

# %%
cat_path = "datasett-hundogkatt/training_set/training_set/cats/"
dog_path = "datasett-hundogkatt/training_set/training_set/dogs/"

# %%
cat_img = []
for i in os.listdir(cat_path):
    if i.endswith(".jpg"):
        temp_img = cv2.imread(os.path.join(cat_path, i), cv2.IMREAD_GRAYSCALE)
        temp_img = cv2.resize(temp_img, (64,64), interpolation= cv2.INTER_LINEAR )
        cat_img.append(temp_img)

# %%
cat_img = np.asarray(cat_img)
cat_img = np.expand_dims(cat_img,-1)

# %%
y_cat = np.zeros(cat_img.shape[0])

# %%
dog_img = []
for i in os.listdir(dog_path):
    if i.endswith(".jpg"):
        temp_img = cv2.imread(os.path.join(dog_path, i), cv2.IMREAD_GRAYSCALE)
        temp_img = cv2.resize(temp_img, (64,64), interpolation= cv2.INTER_LINEAR )
        dog_img.append(temp_img)

# %%
dog_img = np.asarray(dog_img)
dog_img = np.expand_dims(dog_img,-1)

# %%
y_dog = np.ones(dog_img.shape[0])

# %%
plt.figure(figsize=(20,8))
for i in range(10):
    plt.subplot(2,5,i+1)
    plt.imshow(cat_img[i],cmap='gray', vmin=0, vmax=255)

# %%
plt.figure(figsize=(20,8))
for i in range(10):
    plt.subplot(2,5,i+1)
    plt.imshow(dog_img[i],cmap='gray', vmin=0, vmax=255)

# %%
X = np.vstack([cat_img,dog_img])

# %%
y = np.hstack([y_cat,y_dog])

# %%
X_train, X_val, y_train, y_val = train_test_split(X,y, test_size=0.2)

# %%
np.unique(y_train, return_counts=True)
# Out:
# (array([0., 1.]), array([3179, 3225], dtype=int64))

# %%
np.unique(y_val, return_counts=True)
# Out:
# (array([0., 1.]), array([821, 780], dtype=int64))

# %%
y_train = np.expand_dims(y_train ,-1)

# %%
X_train.shape
# Out:
# (6404, 64, 64, 1)

# %%
model = tf.keras.Sequential()
model.add(tf.keras.layers.Conv2D(6, 5, activation='tanh', input_shape=(X_train.shape[1],X_train.shape[2],1)))
model.add(tf.keras.layers.AveragePooling2D(2))
model.add(tf.keras.layers.Activation('sigmoid'))
model.add(tf.keras.layers.Conv2D(16, 5, activation='tanh'))
model.add(tf.keras.layers.AveragePooling2D(2))
model.add(tf.keras.layers.Activation('sigmoid'))
model.add(tf.keras.layers.Conv2D(120, 4, activation='tanh'))
model.add(tf.keras.layers.Flatten())
model.add(tf.keras.layers.Dense(84, activation='tanh'))
model.add(tf.keras.layers.Dense(1, activation='sigmoid'))
model.summary()
# Out:
# Model: "sequential_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_18 (Conv2D)          (None, 60, 60, 6)         156
#
#  average_pooling2d_12 (Avera  (None, 30, 30, 6)        0
#  gePooling2D)
#
#  activation_12 (Activation)  (None, 30, 30, 6)         0
#
#  conv2d_19 (Conv2D)          (None, 26, 26, 16)        2416
#
#  average_pooling2d_13 (Avera  (None, 13, 13, 16)       0
#  gePooling2D)
#
#  activation_13 (Activation)  (None, 13, 13, 16)        0
#
#  conv2d_20 (Conv2D)          (None, 10, 10, 120)       30840
#
#  flatten_6 (Flatten)         (None, 12000)             0
#
#  dense_12 (Dense)            (None, 84)                1008084
#
#  dense_13 (Dense)            (None, 1)                 85
#
# =================================================================
# Total params: 1,041,581
# Trainable params: 1,041,581
# Non-trainable params: 0
# _________________________________________________________________

# %%
model = tf.keras.Sequential()
model.add(tf.keras.layers.Conv2D(6, 5, activation='relu', input_shape=(X_train.shape[1],X_train.shape[2],1)))
model.add(tf.keras.layers.AveragePooling2D(2))
model.add(tf.keras.layers.Activation('relu'))
model.add(tf.keras.layers.Conv2D(16, 5, activation='relu'))
model.add(tf.keras.layers.AveragePooling2D(2))
model.add(tf.keras.layers.Activation('relu'))
model.add(tf.keras.layers.Conv2D(120, 5, activation='relu'))
model.add(tf.keras.layers.Flatten())
model.add(tf.keras.layers.Dense(84, activation='relu'))
model.add(tf.keras.layers.Dense(1, activation='sigmoid'))
model.summary()
# Out:
# Model: "sequential_8"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_24 (Conv2D)          (None, 60, 60, 6)         156
#
#  average_pooling2d_16 (Avera  (None, 30, 30, 6)        0
#  gePooling2D)
#
#  activation_16 (Activation)  (None, 30, 30, 6)         0
#
#  conv2d_25 (Conv2D)          (None, 26, 26, 16)        2416
#
#  average_pooling2d_17 (Avera  (None, 13, 13, 16)       0
#  gePooling2D)
#
#  activation_17 (Activation)  (None, 13, 13, 16)        0
#
#  conv2d_26 (Conv2D)          (None, 9, 9, 120)         48120
#
#  flatten_8 (Flatten)         (None, 9720)              0
#
#  dense_16 (Dense)            (None, 84)                816564
#
#  dense_17 (Dense)            (None, 1)                 85
#
# =================================================================
# Total params: 867,341
# Trainable params: 867,341
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(loss="binary_crossentropy", optimizer=tf.keras.optimizers.Adam(learning_rate=0.00001), 
                metrics = [tf.keras.metrics.BinaryAccuracy(),tf.keras.metrics.AUC(curve='ROC')])

# %%
history = model.fit(x=X_train,y=y_train, epochs=25, batch_size=64, validation_data=(X_val,y_val), shuffle=True)
# Out:
# Epoch 1/25
# 101/101 [==============================] - 16s 104ms/step - loss: 0.9314 - binary_accuracy: 0.5220 - auc_6: 0.5283 - val_loss: 0.7924 - val_binary_accuracy: 0.5172 - val_auc_6: 0.5361
# Epoch 2/25
# 101/101 [==============================] - 14s 143ms/step - loss: 0.7389 - binary_accuracy: 0.5654 - auc_6: 0.5898 - val_loss: 0.7393 - val_binary_accuracy: 0.5572 - val_auc_6: 0.5770
# Epoch 3/25
# 101/101 [==============================] - 13s 132ms/step - loss: 0.6879 - binary_accuracy: 0.5967 - auc_6: 0.6405 - val_loss: 0.7159 - val_binary_accuracy: 0.5765 - val_auc_6: 0.6134
# Epoch 4/25
# 101/101 [==============================] - 15s 149ms/step - loss: 0.6526 - binary_accuracy: 0.6307 - auc_6: 0.6816 - val_loss: 0.7074 - val_binary_accuracy: 0.5815 - val_auc_6: 0.6299
# Epoch 5/25
# 101/101 [==============================] - 15s 146ms/step - loss: 0.6291 - binary_accuracy: 0.6544 - auc_6: 0.7078 - val_loss: 0.6913 - val_binary_accuracy: 0.5978 - val_auc_6: 0.6401
# Epoch 6/25
# 101/101 [==============================] - 15s 147ms/step - loss: 0.6118 - binary_accuracy: 0.6666 - auc_6: 0.7283 - val_loss: 0.6978 - val_binary_accuracy: 0.5965 - val_auc_6: 0.6523
# Epoch 7/25
# 101/101 [==============================] - 14s 143ms/step - loss: 0.5901 - binary_accuracy: 0.6871 - auc_6: 0.7524 - val_loss: 0.6858 - val_binary_accuracy: 0.6021 - val_auc_6: 0.6577
# Epoch 8/25
# 101/101 [==============================] - 14s 142ms/step - loss: 0.5732 - binary_accuracy: 0.6983 - auc_6: 0.7695 - val_loss: 0.6830 - val_binary_accuracy: 0.6127 - val_auc_6: 0.6665
# Epoch 9/25
# 101/101 [==============================] - 15s 150ms/step - loss: 0.5565 - binary_accuracy: 0.7131 - auc_6: 0.7873 - val_loss: 0.6721 - val_binary_accuracy: 0.6184 - val_auc_6: 0.6724
# Epoch 10/25
# 101/101 [==============================] - 15s 145ms/step - loss: 0.5406 - binary_accuracy: 0.7242 - auc_6: 0.8024 - val_loss: 0.7004 - val_binary_accuracy: 0.6171 - val_auc_6: 0.6810
# Epoch 11/25
# 101/101 [==============================] - 15s 146ms/step - loss: 0.5279 - binary_accuracy: 0.7344 - auc_6: 0.8145 - val_loss: 0.6719 - val_binary_accuracy: 0.6290 - val_auc_6: 0.6813
# Epoch 12/25
# 101/101 [==============================] - 15s 147ms/step - loss: 0.5128 - binary_accuracy: 0.7492 - auc_6: 0.8279 - val_loss: 0.6800 - val_binary_accuracy: 0.6296 - val_auc_6: 0.6892
# Epoch 13/25
# 101/101 [==============================] - 15s 148ms/step - loss: 0.4997 - binary_accuracy: 0.7587 - auc_6: 0.8386 - val_loss: 0.6589 - val_binary_accuracy: 0.6284 - val_auc_6: 0.6914
# Epoch 14/25
# 101/101 [==============================] - 15s 148ms/step - loss: 0.4843 - binary_accuracy: 0.7686 - auc_6: 0.8519 - val_loss: 0.6646 - val_binary_accuracy: 0.6309 - val_auc_6: 0.6923
# Epoch 15/25
# 101/101 [==============================] - 14s 137ms/step - loss: 0.4726 - binary_accuracy: 0.7756 - auc_6: 0.8609 - val_loss: 0.6662 - val_binary_accuracy: 0.6277 - val_auc_6: 0.6964
# Epoch 16/25
# 101/101 [==============================] - 15s 147ms/step - loss: 0.4610 - binary_accuracy: 0.7865 - auc_6: 0.8708 - val_loss: 0.6632 - val_binary_accuracy: 0.6483 - val_auc_6: 0.7035
# Epoch 17/25
# 101/101 [==============================] - 15s 147ms/step - loss: 0.4509 - binary_accuracy: 0.7959 - auc_6: 0.8770 - val_loss: 0.6621 - val_binary_accuracy: 0.6421 - val_auc_6: 0.7020
# Epoch 18/25
# 101/101 [==============================] - 15s 146ms/step - loss: 0.4363 - binary_accuracy: 0.8029 - auc_6: 0.8890 - val_loss: 0.6608 - val_binary_accuracy: 0.6458 - val_auc_6: 0.7046
# Epoch 19/25
# 101/101 [==============================] - 15s 152ms/step - loss: 0.4180 - binary_accuracy: 0.8209 - auc_6: 0.9032 - val_loss: 0.6543 - val_binary_accuracy: 0.6540 - val_auc_6: 0.7115
# Epoch 20/25
# 101/101 [==============================] - 16s 157ms/step - loss: 0.4081 - binary_accuracy: 0.8257 - auc_6: 0.9090 - val_loss: 0.6620 - val_binary_accuracy: 0.6521 - val_auc_6: 0.7143
# Epoch 21/25
# 101/101 [==============================] - 17s 164ms/step - loss: 0.3989 - binary_accuracy: 0.8301 - auc_6: 0.9137 - val_loss: 0.6561 - val_binary_accuracy: 0.6540 - val_auc_6: 0.7146
# Epoch 22/25
# 101/101 [==============================] - 15s 149ms/step - loss: 0.3844 - binary_accuracy: 0.8403 - auc_6: 0.9237 - val_loss: 0.6589 - val_binary_accuracy: 0.6558 - val_auc_6: 0.7151
# Epoch 23/25
# 101/101 [==============================] - 15s 146ms/step - loss: 0.3749 - binary_accuracy: 0.8434 - auc_6: 0.9276 - val_loss: 0.6644 - val_binary_accuracy: 0.6527 - val_auc_6: 0.7149
# Epoch 24/25
# 101/101 [==============================] - 17s 171ms/step - loss: 0.3616 - binary_accuracy: 0.8577 - auc_6: 0.9364 - val_loss: 0.6714 - val_binary_accuracy: 0.6452 - val_auc_6: 0.7163
# Epoch 25/25
# 101/101 [==============================] - 16s 163ms/step - loss: 0.3550 - binary_accuracy: 0.8645 - auc_6: 0.9404 - val_loss: 0.6678 - val_binary_accuracy: 0.6608 - val_auc_6: 0.7225

# %%
plt.figure(figsize=(12,8))
plt.plot(history.history["loss"], label="loss")
plt.plot(history.history["val_loss"], label="val_loss")
plt.legend()

# %%
history.history.keys()
# Out:
# dict_keys(['loss', 'binary_accuracy', 'auc_6', 'val_loss', 'val_binary_accuracy', 'val_auc_6'])

# %%
plt.figure(figsize=(12,8))
plt.plot(history.history[list(history.history.keys())[2]], label="AUROC")
plt.plot(history.history[list(history.history.keys())[5]], label="val_AUROC")
plt.legend()
